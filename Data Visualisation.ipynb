# %% [markdown]
# **1. Distinct room type counts**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The dataset is heavily dominated by "Entire place" and "Private room" listings, whereas "Shared rooms" make up a negligible fraction of the available accommodations.**

# %% [markdown]
# **2. Average price by room type**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **As expected, the level of privacy directly dictates the cost: "Entire place" listings command the highest average price, followed by "Private rooms," while "Shared rooms" are the most affordable option.**

# %% [markdown]
# **3. Price vs rating by room type**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **As we can see, surprisingly, the scatter plot reveals no distinct correlation between a listing's price and its rating across all room types. Both budget-friendly and premium options frequently achieve similar scores, with the vast majority of ratings heavily concentrated between 4.0 and 5.0, regardless of the price point.**

# %% [markdown]
# **4. Histplot of log_price counts for each room type**

# %% [markdown]
# ![image.png](attachment:03a2a3cf-75dc-47fe-a636-a587ee71cffa.png)

# %% [markdown]
# **In this plot we can see a log transformation on price column, the price density distributions reveal that Entire place listings have a significantly higher median and greater variance than Private Rooms, which maintain a more concentrated and lower price distribution.**

# %% [markdown]
# **5. Price brackets counts for each room type**

# %% [markdown]
# ![image.png](attachment:de9aa8fa-d2aa-4e92-98b7-34667b70ed9f.png)

# %% [markdown]
# **The binned frequency analysis shows a clear price threshold at $100, below which Private Rooms are the most frequent, whereas Entire places exhibit a much broader range and become the dominant listing type in every price bracket exceeding that mark.**

# %% [markdown]
# **6. How diverse the room offers are in different districts**

# %% [markdown]
# ![image.png](attachment:f3737375-b569-4a82-ad12-4d9f0e80b93e.png)

# %% [markdown]
# **This categorical count plot illustrates that Manhattan is the primary hub for Entire place listings, while Brooklyn dominates the Private Room market segment, with Shared rooms representing a statistically marginal fraction across all boroughs.**

# %% [markdown]
# ### 1. Distribution of Listing Ratings
# ![image.png](attachment:850b862b-d8ad-4627-860d-292595ce9bfe.png)
# ##### This histogram illustrates the distribution of guest ratings across all active listings. After treating out-of-range data anomalies (capping maximum ratings at 5.0), the visualization reveals the general satisfaction level of guests. The density curve helps identify whether the market leans toward highly positive feedback or if there is a wider spread of guest experiences.

# %% [markdown]
# ### 2. Price Distribution by Room Type
# ![image.png](attachment:c3d913c5-a17b-41e9-8e7c-055b3132ea32.png)
# ##### This boxplot breaks down the cost per night across distinct housing categories: Entire place, Private Room, and Shared room. To provide a clearer view of the typical market, extreme luxury outliers (listings over $500/night) were filtered out. The chart effectively highlights the median prices, the interquartile price variances, and the typical price ceilings for each specific room type.

# %% [markdown]
# ### 3. Number of Reviews vs. Price
#
# ![image.png](attachment:55459df6-a308-4ad7-9802-a2e230816dc5.png)
# ##### This scatterplot explores the relationship between a listing's nightly price and the total number of reviews it has received (used here as a proxy for booking frequency/popularity). The data points are color-coded by room type. The clustering of data reveals an inverse relationship: more affordable listings tend to accumulate a significantly higher volume of reviews, indicating that budget-friendly options experience the highest guest turnover.
